# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('AviationData.csv',encoding='latin-1',low_memory =False)
df2= pd.read_csv("USState_Codes.csv")

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
df2.head()
# Out:
#      US_State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
df3= pd.concat([df,df2])

# %%
df3.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Total.Fatal.Injuries Total.Serious.Injuries  \
# 0          NaN  ...                  2.0                    0.0
# ...

# %%
df3.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
df3.shape
# Out:
# (88951, 33)

# %% [markdown]
# so we need to identify the missing data and evaluate the duplicated rows in the data set in order for our

# %%
duplicated = df3.duplicated().sum()
print(f"This dataset has {duplicated} duplicate rows")
# Out:
# This dataset has 0 duplicate rows

# %%
so we need to identify the missing data and evaluate which data set has been duplicated rows.
# Out:
#   Cell In[21], line 1
#     so we need to identify the missing data and evaluate which data set has been duplicated rows.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# identify missing data

# %%
missing_values = df3.isna().sum().sort_values(ascending=False)
missing_values
# Out:
# Abbreviation              88889
# US_State                  88889
# Schedule                  76369
# Air.carrier               72303
# FAR.Description           56928
# Aircraft.Category         56664
# Longitude                 54578
# Latitude                  54569
# Airport.Code              38819
# Airport.Name              36247
# Broad.phase.of.flight     27227
# Publication.Date          13833
# Total.Serious.Injuries    12572
# Total.Minor.Injuries      11995
# Total.Fatal.Injuries      11463
# Engine.Type                7158
# Report.Status              6446
# Purpose.of.flight          6254
# Number.of.Engines          6146
# Total.Uninjured            5974
# Weather.Condition          4554
# Aircraft.damage            3256
# Registration.Number        1444
# Injury.Severity            1062
# Country                     288
# Amateur.Built               164
# Model                       154
# Make                        125
# Location                    114
# ...

# %%
missing_values_df3 = missing_values.reset_index()
